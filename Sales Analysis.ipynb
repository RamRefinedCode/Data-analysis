# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('transaction.csv',sep=';')

# %%
df.head()
# Out:
#    UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb    2  12:50:00    465549
# 1  337701        6283376  2018   Dec   26  09:06:00    482370
# 2  267099        6385599  2019   Feb   15  09:45:00    490728
# 3  380478        6044973  2018   Jun   22  07:14:00    459186
# 4      -1        6143225  2018   Sep   10  11:58:00   1733592
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# 1              LONDON BUS COFFEE MUG                       3         3.52
# 2  SET 12 COLOUR PENCILS DOLLY GIRL                       72         0.90
# 3        UNION JACK FLAG LUGGAGE TAG                       3         1.73
# 4                WASHROOM METAL SIGN                       3         3.40
#
#    SellingPricePerItem         Country  \
# 0                21.11  United Kingdom
# 1                 3.87  United Kingdom
# ...

# %%
#summary of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1047588 entries, 0 to 1047587
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   UserId                  1047588 non-null  int64
#  1   TransactionId           1047588 non-null  int64
#  2   Year                    1047588 non-null  int64
#  3   Month                   1047588 non-null  object
#  4   Day                     1047588 non-null  int64
#  5   Time                    1047588 non-null  object
#  6   ItemCode                1047588 non-null  int64
#  7   ItemDescription         1044797 non-null  object
#  8   NumberOfItemsPurchased  1047588 non-null  int64
#  9   CostPerItem             1047588 non-null  float64
#  10  SellingPricePerItem     1047588 non-null  float64
#  11  Country                 1047588 non-null  object
#  12  ClientKeywords          1047588 non-null  object
# dtypes: float64(2), int64(6), object(5)
# ...

# %%
df['Salespertransaction'] = df['NumberOfItemsPurchased']*df['SellingPricePerItem']

# %%
df['Salespertransaction']
# Out:
# 0          126.66
# 1           11.61
# 2          116.64
# 3            5.70
# 4           17.34
#             ...
# 1047583     24.87
# 1047584     63.36
# 1047585     37.65
# 1047586     15.54
# 1047587     36.72
# Name: Salespertransaction, Length: 1047588, dtype: float64

# %%
df['Profit'] = df['Salespertransaction']-df['CostPerItem']*df['NumberOfItemsPurchased']

# %%
df['Profit']
# Out:
# 0          56.28
# 1           1.05
# 2          51.84
# 3           0.51
# 4           7.14
#            ...
# 1047583     9.33
# 1047584     5.76
# 1047585     3.45
# 1047586     6.90
# 1047587    16.32
# Name: Profit, Length: 1047588, dtype: float64

# %%
# remove = ['Total_price']
# df = df.drop(remove,axis=1)
# df.head()

# %%
df['Costpertransaction'] = df['CostPerItem'] * df['NumberOfItemsPurchased']

# %%
df.head()
# Out:
#    UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb    2  12:50:00    465549
# 1  337701        6283376  2018   Dec   26  09:06:00    482370
# 2  267099        6385599  2019   Feb   15  09:45:00    490728
# 3  380478        6044973  2018   Jun   22  07:14:00    459186
# 4      -1        6143225  2018   Sep   10  11:58:00   1733592
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# 1              LONDON BUS COFFEE MUG                       3         3.52
# 2  SET 12 COLOUR PENCILS DOLLY GIRL                       72         0.90
# 3        UNION JACK FLAG LUGGAGE TAG                       3         1.73
# 4                WASHROOM METAL SIGN                       3         3.40
#
#    SellingPricePerItem         Country  \
# 0                21.11  United Kingdom
# 1                 3.87  United Kingdom
# ...

# %%
df['Markup'] = round(df['Profit']/df['Costpertransaction'],2)

# %%
df.head()
# Out:
#    UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb    2  12:50:00    465549
# 1  337701        6283376  2018   Dec   26  09:06:00    482370
# 2  267099        6385599  2019   Feb   15  09:45:00    490728
# 3  380478        6044973  2018   Jun   22  07:14:00    459186
# 4      -1        6143225  2018   Sep   10  11:58:00   1733592
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# 1              LONDON BUS COFFEE MUG                       3         3.52
# 2  SET 12 COLOUR PENCILS DOLLY GIRL                       72         0.90
# 3        UNION JACK FLAG LUGGAGE TAG                       3         1.73
# 4                WASHROOM METAL SIGN                       3         3.40
#
#    SellingPricePerItem         Country  \
# 0                21.11  United Kingdom
# 1                 3.87  United Kingdom
# ...

# %%
Day = df['Day'].astype(str)

# %%
Year = df['Year'].astype(str)
Month = df['Month'].astype(str)

# %%
Date = Day + '-'+ Month + '-' + Year

# %%
Date
# Out:
# 0           2-Feb-2019
# 1          26-Dec-2018
# 2          15-Feb-2019
# 3          22-Jun-2018
# 4          10-Sep-2018
#               ...
# 1047583    16-Feb-2019
# 1047584    15-Jan-2019
# 1047585     8-Sep-2018
# 1047586    20-Jul-2018
# 1047587    10-Oct-2018
# Length: 1047588, dtype: object

# %%
from datetime import datetime

# %%
Date = pd.to_datetime(Date)

# %%
Date.dt.year.value_counts()
# Out:
# 2018    783606
# 2019    258245
# 2028      5737
# dtype: int64

# %%
df['Date'] = Date

# %%
df
# Out:
#          UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0        278166        6355745  2019   Feb    2  12:50:00    465549
# 1        337701        6283376  2018   Dec   26  09:06:00    482370
# 2        267099        6385599  2019   Feb   15  09:45:00    490728
# 3        380478        6044973  2018   Jun   22  07:14:00    459186
# 4            -1        6143225  2018   Sep   10  11:58:00   1733592
# ...         ...            ...   ...   ...  ...       ...       ...
# 1047583  343560        6386952  2019   Feb   16  08:16:00    450030
# 1047584  276528        6316717  2019   Jan   15  08:56:00   1732143
# 1047585  341082        6140585  2018   Sep    8  10:41:00    487326
# 1047586  336147        6075190  2018   Jul   20  09:32:00    460509
# 1047587      -1        6180020  2018   Oct   10  12:00:00    473739
#
#                             ItemDescription  NumberOfItemsPurchased  \
# 0          FAMILY ALBUM WHITE PICTURE FRAME                       6
# ...

# %%
df.iloc[0:5]
# Out:
#    UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb    2  12:50:00    465549
# 1  337701        6283376  2018   Dec   26  09:06:00    482370
# 2  267099        6385599  2019   Feb   15  09:45:00    490728
# 3  380478        6044973  2018   Jun   22  07:14:00    459186
# 4      -1        6143225  2018   Sep   10  11:58:00   1733592
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# 1              LONDON BUS COFFEE MUG                       3         3.52
# 2  SET 12 COLOUR PENCILS DOLLY GIRL                       72         0.90
# 3        UNION JACK FLAG LUGGAGE TAG                       3         1.73
# 4                WASHROOM METAL SIGN                       3         3.40
#
#    SellingPricePerItem         Country  \
# 0                21.11  United Kingdom
# 1                 3.87  United Kingdom
# ...

# %%
df.iloc[:,3]
# Out:
# 0          Feb
# 1          Dec
# 2          Feb
# 3          Jun
# 4          Sep
#           ...
# 1047583    Feb
# 1047584    Jan
# 1047585    Sep
# 1047586    Jul
# 1047587    Oct
# Name: Month, Length: 1047588, dtype: object

# %%
df.iloc[4,2]
# Out:
# 2018

# %%
df.head(3)
# Out:
#    UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb    2  12:50:00    465549
# 1  337701        6283376  2018   Dec   26  09:06:00    482370
# 2  267099        6385599  2019   Feb   15  09:45:00    490728
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# 1              LONDON BUS COFFEE MUG                       3         3.52
# 2  SET 12 COLOUR PENCILS DOLLY GIRL                       72         0.90
#
#    SellingPricePerItem         Country  \
# 0                21.11  United Kingdom
# 1                 3.87  United Kingdom
# 2                 1.62          France
#
#                                       ClientKeywords  Salespertransaction  \
# 0  ['Senior', 'Solo Entrepreneur', '2-5 Year Clie...               126.66
# 1   ['Middle Age', 'Corporation', '2-5 Year Client']                11.61
# ...

# %%
split_col = df['ClientKeywords'].str.split(',',expand=True)

# %%
df['ClientAge'] = split_col[0]
df['ClientType'] = split_col[1]
df['LengthofContract'] = split_col[2]

# %%
df.head(3)
# Out:
#    UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb    2  12:50:00    465549
# 1  337701        6283376  2018   Dec   26  09:06:00    482370
# 2  267099        6385599  2019   Feb   15  09:45:00    490728
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# 1              LONDON BUS COFFEE MUG                       3         3.52
# 2  SET 12 COLOUR PENCILS DOLLY GIRL                       72         0.90
#
#    ...         Country                                     ClientKeywords  \
# 0  ...  United Kingdom  ['Senior', 'Solo Entrepreneur', '2-5 Year Clie...
# 1  ...  United Kingdom   ['Middle Age', 'Corporation', '2-5 Year Client']
# 2  ...          France   ['Middle Age', 'Corporation', '2-5 Year Client']
#
#   Salespertransaction  Profit  Costpertransaction  Markup       Date  \
# ...

# %%
name ='[sriram'
name[1:]
# Out:
# 'sriram'

# %%
def name(name):
    return name[1:]

# %%
name('[sriram')
# Out:
# 'sriram'

# %%
df['ClientAge'] = df['ClientAge'].apply(name)

# %%
def name1(name):
    return name[:-1]

# %%
name1('sriram]')
# Out:
# 'sriram'

# %%
df['LengthofContract'] = df['LengthofContract'].apply(name1)

# %%
df.head(3)
# Out:
#    UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb    2  12:50:00    465549
# 1  337701        6283376  2018   Dec   26  09:06:00    482370
# 2  267099        6385599  2019   Feb   15  09:45:00    490728
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# 1              LONDON BUS COFFEE MUG                       3         3.52
# 2  SET 12 COLOUR PENCILS DOLLY GIRL                       72         0.90
#
#    ...         Country                                     ClientKeywords  \
# 0  ...  United Kingdom  ['Senior', 'Solo Entrepreneur', '2-5 Year Clie...
# 1  ...  United Kingdom   ['Middle Age', 'Corporation', '2-5 Year Client']
# 2  ...          France   ['Middle Age', 'Corporation', '2-5 Year Client']
#
#   Salespertransaction  Profit  Costpertransaction  Markup       Date  \
# ...

# %%
df['ItemDescription'] = df['ItemDescription'].str.lower()

# %%
df.head(3)
# Out:
#    UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb    2  12:50:00    465549
# 1  337701        6283376  2018   Dec   26  09:06:00    482370
# 2  267099        6385599  2019   Feb   15  09:45:00    490728
#
#                      ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0   family album white picture frame                       6        11.73
# 1              london bus coffee mug                       3         3.52
# 2  set 12 colour pencils dolly girl                       72         0.90
#
#    ...         Country                                     ClientKeywords  \
# 0  ...  United Kingdom  ['Senior', 'Solo Entrepreneur', '2-5 Year Clie...
# 1  ...  United Kingdom   ['Middle Age', 'Corporation', '2-5 Year Client']
# 2  ...          France   ['Middle Age', 'Corporation', '2-5 Year Client']
#
#   Salespertransaction  Profit  Costpertransaction  Markup       Date  \
# ...

# %%
df1 = pd.read_csv('4.4 value_inc_seasons.csv')

# %%
df1
# Out:
#    Month Season
# 0    Jan   High
# 1    Feb    Mid
# 2    Mar    Low
# 3    Apr    Low
# 4    May    Low
# 5    Jun   High
# 6    Jul   High
# 7    Aug   High
# 8    Sep    Mid
# 9    Oct    Low
# 10   Nov    Low
# 11   Dec   High

# %%
df = pd.merge(df,df1,on='Month')

# %%
df.head(3)
# Out:
#    UserId  TransactionId  Year Month  Day      Time  ItemCode  \
# 0  278166        6355745  2019   Feb    2  12:50:00    465549
# 1  267099        6385599  2019   Feb   15  09:45:00    490728
# 2  328440        6387425  2019   Feb   16  10:35:00    494802
#
#                        ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0     family album white picture frame                       6        11.73
# 1    set 12 colour pencils dolly girl                       72         0.90
# 2  set of 6 ribbons perfectly pretty                        36         3.99
#
#    ...                                     ClientKeywords Salespertransaction  \
# 0  ...  ['Senior', 'Solo Entrepreneur', '2-5 Year Clie...              126.66
# 1  ...   ['Middle Age', 'Corporation', '2-5 Year Client']              116.64
# 2  ...          ['Adult', 'Small Business', 'New Client']              201.24
#
#   Profit  Costpertransaction  Markup       Date     ClientAge  \
# ...

# %%
drop = ['ClientKeywords','Year','Month','Day']

# %%
df = df.drop(drop,axis=1)

# %%
df.head(4)
# Out:
#    UserId  TransactionId      Time  ItemCode  \
# 0  278166        6355745  12:50:00    465549
# 1  267099        6385599  09:45:00    490728
# 2  328440        6387425  10:35:00    494802
# 3  364791        6358242  09:25:00    486276
#
#                        ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0     family album white picture frame                       6        11.73
# 1    set 12 colour pencils dolly girl                       72         0.90
# 2  set of 6 ribbons perfectly pretty                        36         3.99
# 3        set of 5 mini grocery magnets                       3         2.88
#
#    SellingPricePerItem         Country  Salespertransaction  Profit  \
# 0                21.11  United Kingdom               126.66   56.28
# 1                 1.62          France               116.64   51.84
# 2                 5.59  United Kingdom               201.24   57.60
# 3                 3.74  United Kingdom                11.22    2.58
#
# ...

# %%
df.to_csv('ValueInc_Cleaned.csv',index=False)
